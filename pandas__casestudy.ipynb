# %% [markdown]
# <a href="https://colab.research.google.com/github/jkrish006/Pandas_case_study/blob/main/pandas__casestudy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import pandas, numpy
import numpy as np
import pandas as pd

# %%
# Load dataset using pd.read_csv()
data= pd.read_csv("/content/IMDB-Movie-Data.csv")
data
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
# Display: shape, head, column names, datatypes, missing value
data.shape
# Out:
# (1000, 12)

# %%
data.head()
# Out:
#    Rank                    Title                     Genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
# 3     4                     Sing   Animation,Comedy,Family
# 4     5            Suicide Squad  Action,Adventure,Fantasy
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4  A secret government agency recruits some of th...            David Ayer
#
#                                               Actors  Year  Runtime (Minutes)  \
# ...

# %%
data.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
data.dtypes
# Out:
# Rank                    int64
# Title                  object
# Genre                  object
# Description            object
# Director               object
# Actors                 object
# Year                    int64
# Runtime (Minutes)       int64
# Rating                float64
# Votes                   int64
# Revenue (Millions)    float64
# Metascore             float64
# dtype: object

# %%
data.isna()
# Out:
#       Rank  Title  Genre  Description  Director  Actors   Year  \
# 0    False  False  False        False     False   False  False
# 1    False  False  False        False     False   False  False
# 2    False  False  False        False     False   False  False
# 3    False  False  False        False     False   False  False
# 4    False  False  False        False     False   False  False
# ..     ...    ...    ...          ...       ...     ...    ...
# 995  False  False  False        False     False   False  False
# 996  False  False  False        False     False   False  False
# 997  False  False  False        False     False   False  False
# 998  False  False  False        False     False   False  False
# 999  False  False  False        False     False   False  False
#
#      Runtime (Minutes)  Rating  Votes  Revenue (Millions)  Metascore
# 0                False   False  False               False      False
# 1                False   False  False               False      False
# ...

# %%
# Check and remove duplicates
data.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Length: 1000, dtype: bool

# %%
data.drop_duplicates()
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
#  Rename columns ("Title" > "Movie_Title")
new_data= data.rename(columns={"Title":"Movie Title"})
new_data
# Out:
#      Rank              Movie Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
unq_genre=data["Genre"].str.split(",").explode().unique()
unq_genre
# Out:
# array(['Action', 'Adventure', 'Sci-Fi', 'Mystery', 'Horror', 'Thriller',
#        'Animation', 'Comedy', 'Family', 'Fantasy', 'Drama', 'Music',
#        'Biography', 'Romance', 'History', 'Crime', 'Western', 'War',
#        'Musical', 'Sport'], dtype=object)

# %%
new_data["Genre count"]=new_data["Genre"].str.split(",").str.len()
new_data[["Movie Title","Genre","Genre count"]]
# Out:
#                  Movie Title                     Genre  Genre count
# 0    Guardians of the Galaxy   Action,Adventure,Sci-Fi            3
# 1                 Prometheus  Adventure,Mystery,Sci-Fi            3
# 2                      Split           Horror,Thriller            2
# 3                       Sing   Animation,Comedy,Family            3
# 4              Suicide Squad  Action,Adventure,Fantasy            3
# ..                       ...                       ...          ...
# 995     Secret in Their Eyes       Crime,Drama,Mystery            3
# 996          Hostel: Part II                    Horror            1
# 997   Step Up 2: The Streets       Drama,Music,Romance            3
# 998             Search Party          Adventure,Comedy            2
# 999               Nine Lives     Comedy,Family,Fantasy            3
#
# [1000 rows x 3 columns]

# %%
new_data[[ "Revenue (Millions)","Metascore"]].isna().sum()
new_data[["Revenue (Millions)","Metascore"]] = new_data[["Revenue (Millions)", "Metascore"]].fillna(1)

new_data[["Revenue (Millions)","Metascore"]].isna().sum()
# Out:
# Revenue (Millions)    0
# Metascore             0
# dtype: int64

# %%
new_data.sort_values(by="Rating",ascending = False).head(5)
# Out:
#      Rank       Movie Title                    Genre  \
# 54     55   The Dark Knight       Action,Crime,Drama
# 80     81         Inception  Action,Adventure,Sci-Fi
# 117   118            Dangal   Action,Biography,Drama
# 36     37      Interstellar   Adventure,Drama,Sci-Fi
# 249   250  The Intouchables   Biography,Comedy,Drama
#
#                                            Description           Director  \
# 54   When the menace known as the Joker wreaks havo...  Christopher Nolan
# 80   A thief, who steals corporate secrets through ...  Christopher Nolan
# 117  Former wrestler Mahavir Singh Phogat and his t...      Nitesh Tiwari
# 36   A team of explorers travel through a wormhole ...  Christopher Nolan
# 249  After he becomes a quadriplegic from a paragli...    Olivier Nakache
#
#                                                 Actors  Year  \
# 54   Christian Bale, Heath Ledger, Aaron Eckhart,Mi...  2008
# 80   Leonardo DiCaprio, Joseph Gordon-Levitt, Ellen...  2010
# ...

# %%
new_revenue=new_data.sort_values(by="Revenue (Millions)", ascending=False)
new_revenue[["Movie Title","Revenue (Millions)"]]
# Out:
#                                     Movie Title  Revenue (Millions)
# 50   Star Wars: Episode VII - The Force Awakens              936.63
# 87                                       Avatar              760.51
# 85                               Jurassic World              652.18
# 76                                 The Avengers              623.28
# 54                              The Dark Knight              533.32
# ..                                          ...                 ...
# 977                               Amateur Night                 NaN
# 978              It's Only the End of the World                 NaN
# 988                                     Martyrs                 NaN
# 995                        Secret in Their Eyes                 NaN
# 998                                Search Party                 NaN
#
# [1000 rows x 2 columns]

# %%
new_data.groupby("Director")["Rating"].mean()
# Out:
# Director
# Aamir Khan             8.50
# Abdellatif Kechiche    7.80
# Adam Leon              6.50
# Adam McKay             7.00
# Adam Shankman          6.30
#                        ...
# Xavier Dolan           7.55
# Yimou Zhang            6.10
# Yorgos Lanthimos       7.20
# Zack Snyder            7.04
# Zackary Adler          5.10
# Name: Rating, Length: 644, dtype: float64

# %%
new_data.groupby("Year").size()
# Out:
# Year
# 2006     44
# 2007     53
# 2008     52
# 2009     51
# 2010     60
# 2011     63
# 2012     64
# 2013     91
# 2014     98
# 2015    127
# 2016    297
# dtype: int64

# %%
new_data[(data["Rating"]> 8)&(data["Revenue (Millions)"]>100)]
# Out:
#      Rank                                   Movie Title  \
# 0       1                       Guardians of the Galaxy
# 6       7                                    La La Land
# 36     37                                  Interstellar
# 50     51    Star Wars: Episode VII - The Force Awakens
# 54     55                               The Dark Knight
# 67     68                            Mad Max: Fury Road
# 74     75                                      Zootopia
# 76     77                                  The Avengers
# 77     78                          Inglourious Basterds
# 80     81                                     Inception
# 82     83                       The Wolf of Wall Street
# 83     84                                     Gone Girl
# 92     93                                      The Help
# 99    100                                  The Departed
# 114   115  Harry Potter and the Deathly Hallows: Part 2
# 124   125                         The Dark Knight Rises
# ...

# %%
new_data.groupby("Director")[["Rating","Revenue (Millions)"]].mean()
# Out:
#                      Rating  Revenue (Millions)
# Director
# Aamir Khan             8.50               1.200
# Abdellatif Kechiche    7.80               2.200
# Adam Leon              6.50                 NaN
# Adam McKay             7.00             109.535
# Adam Shankman          6.30              78.665
# ...                     ...                 ...
# Xavier Dolan           7.55               3.490
# Yimou Zhang            6.10              45.130
# Yorgos Lanthimos       7.20               4.405
# Zack Snyder            7.04             195.148
# Zackary Adler          5.10               6.530
#
# [644 rows x 2 columns]

# %%
new_data.groupby("Year")[["Rating"]].agg(["count","mean"])
# Out:
#      Rating
#       count      mean
# Year
# 2006     44  7.125000
# 2007     53  7.133962
# 2008     52  6.784615
# 2009     51  6.960784
# 2010     60  6.826667
# 2011     63  6.838095
# 2012     64  6.925000
# 2013     91  6.812088
# 2014     98  6.837755
# 2015    127  6.602362
# 2016    297  6.436700

# %%
new_data["Profitability"]=new_data["Revenue (Millions)"]/new_data["Runtime (Minutes)"]
Profitability=new_data.sort_values(by="Profitability",ascending=False).head(10)
Profitability[["Movie Title","Profitability"]]
# Out:
#                                     Movie Title  Profitability
# 50   Star Wars: Episode VII - The Force Awakens       6.886985
# 85                               Jurassic World       5.259516
# 119                                Finding Dory       5.013299
# 87                                       Avatar       4.694506
# 76                                 The Avengers       4.358601
# 15                      The Secret Life of Pets       4.233448
# 688                                 Toy Story 3       4.028932
# 12                                    Rogue One       4.001278
# 174                                      Frozen       3.928824
# 797                             Despicable Me 2       3.755612

# %%
def rating_category(rating):
    if rating < 6:
        return "Poor"
    elif rating < 7.5:
        return "Average"
    else:
        return "Excellent"

new_data["Rating Category"] = new_data["Rating"].apply(rating_category)
new_data
# Out:
#      Rank              Movie Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
new_data["High score"]=new_data["Rating"]*10+new_data["Revenue (Millions)"]
new_data
# Out:
#      Rank              Movie Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...
